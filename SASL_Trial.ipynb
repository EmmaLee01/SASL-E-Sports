# %% [markdown]
# <a href="https://colab.research.google.com/github/EmmaLee01/SASL-E-Sports/blob/branch_Elias/SASL_Trial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests as rq
import json

myAPI = "foE5KBNApBF2PKMt19jmSjKsHsnytXINHXG79Aoa"

headers = {
    "x-api-key": myAPI,
    "Content-Type": "application/json"
}

GRAPHQL_ENDPOINT = "https://api-op.grid.gg/central-data/graphql"
GraphQL_ENDPOINT_LD = "https://api-op.grid.gg/live-data-feed/series-state/graphql"


graphql_query = """
query Series {
    allSeries (
        first: 50,
        filter: {
            titleId: 28
            types: ESPORTS
        }
        orderBy: StartTimeScheduled
        orderDirection: DESC
    ) {
        totalCount
        pageInfo {
            hasPreviousPage
            hasNextPage
            startCursor
            endCursor
        }
        edges {
            node {
                id
                title {
                    id
                }
                tournament {
                    id
                    name
                }
            }
        }
    }
}
"""

payload = {
    "query": graphql_query
}

response = rq.post(GRAPHQL_ENDPOINT, headers=headers, data=json.dumps(payload))

if response.status_code == 200:
    data = response.json()
    print(json.dumps(data, indent=2))
else:
    print(f"Request failed with status code: {response.status_code}")
    print(f"Response: {response.text}")
# Out:
# {
#   "data": {
#     "allSeries": {
#       "totalCount": 14804,
#       "pageInfo": {
#         "hasPreviousPage": false,
#         "hasNextPage": true,
#         "startCursor": "JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFT0NGQENHCwtaCwtFR0VCWkZFWkdBI0ZPTUdHTUdHLQ==",
#         "endCursor": "JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFT0FFQ0NACwtaCwtFR0VCWkZGWkdAI0ZETURHTUdHLQ=="
#       },
#       "edges": [
#         {
#           "node": {
#             "id": "2841740",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "826974",
#               "name": "Svenska Elitserien Fall 2025"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2841739",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "826974",
#               "name": "Svenska Elitserien Fall 2025"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2841738",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "826974",
#               "name": "Svenska Elitserien Fall 2025"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2841737",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "826974",
#               "name": "Svenska Elitserien Fall 2025"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2841736",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "826974",
#               "name": "Svenska Elitserien Fall 2025"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2841735",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "826974",
#               "name": "Svenska Elitserien Fall 2025"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2841734",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "826974",
#               "name": "Svenska Elitserien Fall 2025"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2841733",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "826974",
#               "name": "Svenska Elitserien Fall 2025"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2841732",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "826974",
#               "name": "Svenska Elitserien Fall 2025"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2841731",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "826974",
#               "name": "Svenska Elitserien Fall 2025"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2841730",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "826974",
#               "name": "Svenska Elitserien Fall 2025"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2862302",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "827388",
#               "name": "BLAST Rivals Fall 2025"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2841729",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "826974",
#               "name": "Svenska Elitserien Fall 2025"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2858739",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "827249",
#               "name": "T-esports Championship Season 4"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2862301",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "827388",
#               "name": "BLAST Rivals Fall 2025"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2862300",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "827388",
#               "name": "BLAST Rivals Fall 2025"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2841728",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "826974",
#               "name": "Svenska Elitserien Fall 2025"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2862299",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "827388",
#               "name": "BLAST Rivals Fall 2025"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2862298",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "827388",
#               "name": "BLAST Rivals Fall 2025"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2841727",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "826974",
#               "name": "Svenska Elitserien Fall 2025"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2862297",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "827388",
#               "name": "BLAST Rivals Fall 2025"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2862296",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "827388",
#               "name": "BLAST Rivals Fall 2025"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2862295",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "827388",
#               "name": "BLAST Rivals Fall 2025"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2862294",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "827388",
#               "name": "BLAST Rivals Fall 2025"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2841726",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "826974",
#               "name": "Svenska Elitserien Fall 2025"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2862293",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "827388",
#               "name": "BLAST Rivals Fall 2025"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2862292",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "827388",
#               "name": "BLAST Rivals Fall 2025"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2862291",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "827388",
#               "name": "BLAST Rivals Fall 2025"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2862290",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "827388",
#               "name": "BLAST Rivals Fall 2025"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2841725",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "826974",
#               "name": "Svenska Elitserien Fall 2025"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2863992",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "827407",
#               "name": "United21 Season 40"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2864040",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "827395",
#               "name": "ESL Challenger League Season 50 - Cup #4 North America"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2863958",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "827396",
#               "name": "ESL Challenger League Season 50 - Cup #4 South America"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2864114",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "827394",
#               "name": "ESL Challenger League Season 50 - Cup #4 Europe"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2864066",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "827398",
#               "name": "ESL Challenger League Season 50 - Cup #4 Asia"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2864003",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "827397",
#               "name": "ESL Challenger League Season 50 - Cup #4 Oceania"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2863991",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "827407",
#               "name": "United21 Season 40"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2862455",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "827402",
#               "name": "CCT Season 3 Europe Series 10"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2862454",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "827402",
#               "name": "CCT Season 3 Europe Series 10"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2862453",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "827402",
#               "name": "CCT Season 3 Europe Series 10"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2863990",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "827407",
#               "name": "United21 Season 40"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2863989",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "827407",
#               "name": "United21 Season 40"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2862452",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "827402",
#               "name": "CCT Season 3 Europe Series 10"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2862451",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "827402",
#               "name": "CCT Season 3 Europe Series 10"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2862450",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "827402",
#               "name": "CCT Season 3 Europe Series 10"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2863988",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "827407",
#               "name": "United21 Season 40"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2862449",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "827402",
#               "name": "CCT Season 3 Europe Series 10"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2863987",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "827407",
#               "name": "United21 Season 40"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2862448",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "827402",
#               "name": "CCT Season 3 Europe Series 10"
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "2862447",
#             "title": {
#               "id": "28"
#             },
#             "tournament": {
#               "id": "827402",
#               "name": "CCT Season 3 Europe Series 10"
#             }
#           }
#         }
#       ]
#     }
#   }
# }
